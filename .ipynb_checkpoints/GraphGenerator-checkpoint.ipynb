# %%
import matplotlib.pyplot as plt
import os
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:232: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
os.listdir()
# Out:
# ['CUDAvariedK.txt',
#  'viterbiMPI.cpp',
#  'main.cpp',
#  'viterbiCUDA.cu',
#  'CUDAvariedT.txt',
#  'Makefile',
#  'Untitled.ipynb',
#  '.git',
#  '.ipynb_checkpoints',
#  'cmake-build-debug',
#  'CPUvariedT.txt',
#  'CPUvariedK.txt',
#  'mpiv',
#  'GraphGenerator.ipynb',
#  '.idea',
#  'CMakeLists.txt']

# %%
filek = open("CUDAvariedK.txt", "r")

# %%
contents = filek.read().split("\n")

# %%
Ks = []
Ts = []
Times = []
Flops = []

# %%
for exp in contents[1:-1]:
    
    item = exp.split(",")
    
    Ks.append(int(item[0]))
    Ts.append(int(item[1]))
    Times.append(float(item[2]))
    Flops.append(
    (2*Ks[-1]*Ks[-1]*(Ts[-1]-1)+2*Ks[-1])/Times[-1];
    )
    

print(Ks)
print(Ts)
print(Times)
print(Flops)
# Out:
# [400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400]
# [1000, 1180, 1360, 1540, 1720, 1900, 2080, 2260, 2440, 2620, 2800, 2980, 3160, 3340, 3520, 3700, 3880, 4060, 4240, 4420, 4600, 4780, 4960, 5140, 5320, 5500, 5680, 5860, 6040, 6220, 6400, 6580, 6760, 6940, 7120, 7300, 7480, 7660, 7840, 8020, 8200, 8380, 8560, 8740, 8920, 9100, 9280, 9460, 9640, 9820]
# ...

# %%
plt.plot(Ts,Times)

plt.savefig("CPU_TimevsT")

# %%
plt.plot(Ts,Flops)
plt.savefig("CPU_FlopsvsT")
